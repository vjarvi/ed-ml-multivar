# %%
import pandas as pd
from pyprojroot import here

# %%
data = pd.read_csv(here() / 'data/interim/data.csv', parse_dates=True, index_col='datetime')
data['Target:Occupancy'].describe()
# Out:
# count    21600.000000
# mean        40.164213
# std         20.970151
# min          2.000000
# 25%         22.000000
# 50%         38.000000
# 75%         56.000000
# max        124.000000
# Name: Target:Occupancy, dtype: float64

# %%
(data['Target:Occupancy'] >= 80).value_counts()
# Out:
# False    20808
# True       792
# Name: Target:Occupancy, dtype: int64

# %%
(data['Target:Occupancy'] >= 80).value_counts() / data.shape[0]
# Out:
# False    0.963333
# True     0.036667
# Name: Target:Occupancy, dtype: float64

# %%
data.shape[0]
# Out:
# 21600

# %%
dpo = data['Target:Occupancy'].resample('D').max()
dpo.describe()
# Out:
# count    900.000000
# mean      70.432222
# std       13.572484
# min       32.000000
# 25%       61.000000
# 50%       70.000000
# 75%       80.000000
# max      124.000000
# Name: Target:Occupancy, dtype: float64

# %%
(dpo >= 80).value_counts()
# Out:
# False    665
# True     235
# Name: Target:Occupancy, dtype: int64

# %%
(dpo >= 80).value_counts() / dpo.shape[0]
# Out:
# False    0.738889
# True     0.261111
# Name: Target:Occupancy, dtype: float64

# %%
dpo.shape[0]
# Out:
# 900

# %%
dpo.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
occ = data['Target:Occupancy']
#print position of 2018-06-20
print(occ.index.get_loc('2018-06-20'))
# Out:
# slice(12840, 12864, None)
